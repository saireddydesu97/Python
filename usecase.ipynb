# %% [markdown]
# <a href="https://colab.research.google.com/github/saireddydesu97/Python/blob/main/usecase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import the NumPy library
import numpy as np

# Function to simulate rolling a dice
def roll_dice():
    # Generate a random number between 1 and 6
    dice_value = np.random.randint(1, 7)
    return dice_value

# Main program
print("🎲 Welcome to the Dice Rolling Simulator! 🎲")

while True:
    input("Press Enter to roll the dice... ")
    result = roll_dice()
    print(f"You rolled a {result}!\n")

    # Ask user if they want to roll again
    choice = input("Do you want to roll again? (y/n): ").lower()
    if choice != 'y':
        print("Thanks for playing! Goodbye! 👋")
        break
# Out:
# 🎲 Welcome to the Dice Rolling Simulator! 🎲
# Press Enter to roll the dice...
# You rolled a 4!
#
# Do you want to roll again? (y/n): y
# Press Enter to roll the dice...
# You rolled a 6!
#
# Do you want to roll again? (y/n): n
# Thanks for playing! Goodbye! 👋
